# %% [markdown]
# **QB Variable Ideas**
#
# - fantasy points / game [pfr_fp]
# - consistency [pff_qb_fantasy_week_points]
# -
# - passing yards [pff_qb]
# - passing touchdowns [pff_qb]
# - interceptions [pff_qb]
# - qbr [pff_qb]
# - dropbacks [pff_qb]
# - attempts [pff_qb]
# - completions [pff_qb]
# - deep passing statistics  [pff_deep_passing]
# - intermediate passing statistics [pff_int_passing]
# - short passing statistics [pff_short_passing]
# - behind los passing statistics [pff_behind_los_passing]
# - against zone v man
# - against pressure (Currently pff has a blitzed/not blitzed option, and a pressure/clean option. I prefer the pressure/clean option but pff currently has a glitch where you can't download the pressure/clean option)
# - yards per attempt [pff_qb]
# - average time to throw [pff_qb]
# - sacks taken [pff_qb]
# - scrambles [pff_qb]
# - designed runs (Could just do run attempts - scrambles)
# - rush yardage [pff_rushing]
# - rush tds [pff_rushing]
# - pff pass rating [pff_qb]
# - pff run rating [pff_qb]
# - big time throw rate [pff_qb]
# - turnover worthy play rate [pff_qb]
# - adjusted completion percentage (completions + drops / aimed) [pff_qb]
# - total pressures [pff_qb]
# - percentage of pressures turned into sacks [pff_qb]
# - average depth of target [pff_qb]
# - thrown away [pff_qb]
# - batted passes [pff_qb]
# - Oline pass prot grade [pff_ol]
#
# **I want to use Pressure/Clean instead of Blitzed/Not but PFF is glitched and won't let me download it
#
# Files
