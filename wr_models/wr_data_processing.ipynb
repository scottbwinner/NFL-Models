# %% [markdown]
# Importing NFL Reciever Data

# %% [markdown]
# Data Sources
#     - (NOT SURE YOU CAN PULL FROM HERE) https://nextgenstats.nfl.com/stats/receiving#percent-intended-yards
#     - https://fantasydata.com/nfl/fantasy-football-leaders?season=2023&seasontype=1&scope=1&subscope=1&scoringsystem=2&aggregatescope=1&range=3
#     - https://premium.pff.com/nfl/positions/2023/REGPO/receiving?position=WR,TE,RB,ORCV
#     - https://nflsavant.com/targets.php?ddlYear=2022&ddlPosition=&week=&rz=redzone&ddlTeam=
#     - https://www.pro-football-reference.com/years/2023/fantasy.htm
#     - https://www.pro-football-reference.com/years/2023/
#     - https://premium.pff.com/nfl/positions/2023/REG/ol-pass-blocking-efficiency
#     -
#
# Final Data Sources
#     - pff_receiving: https://premium.pff.com/nfl/positions/2023/REG/receiving-scheme?minimum=1
#     - pff_man_zone: https://premium.pff.com/nfl/positions/2023/REG/receiving
#     - pfr_fp: https://www.pro-football-reference.com/years/2023/fantasy.htm
#     - pfr_rz: https://www.pro-football-reference.com/years/2023/redzone-receiving.htm
#     - pfr_tm_off: https://www.pro-football-reference.com/years/2023/ (Team Offense Table)
#     - pff_ol: https://premium.pff.com/nfl/positions/2023/REG/ol-pass-blocking-efficiency
#     - pff_qb: https://premium.pff.com/nfl/positions/2023/REG/passing?position=QB
#     - qb_depth_chart: https://www.ourlads.com/nfldepthcharts/
#     - pfr_schedule:
#     - pfr_tm_def:
#
# Short term Probblems
# 2023-24 season feature is coming up null
#
# Long term Problems
# 1. Rookies
# 2. Injuries
#     - Could do most previous non injured season
#     - Need to do everything per game
# 3. New teams
# 4. New coaches/schemes
#
# Model Types
#  - Linear Regression
#  - H20 regression
#  - Random Forest
#  - Decision Tree
#  - Gradient Boost
#  - Neural Network
#  - Bayesian Regression
#  - Ensemble Methods (Combine multiple others)
#
# ** Overall Ideas **
# - Maybe it would be interesting to value players by projected points above average (of position) and then have the AI do mock drafts to look at the strategy?
#
#
# **Variable Ideas**
#
# - Last year personal stats:
#     - Fantasy Points per game (PFR [pfr_fantasy])
#     - Target Share
#         - Need to somehow make this per game
#         - Maybe just do Targets per game (PFF [pff_receiving])
#         - Redzone Targets per game (pfr [pfr_rz_rec])
#     - Yards/Game (PFF [pff_receiving])
#     - Catch Rate (PFF [pff_receiving])
#     - Yards after catch (average) (PFF [pff_receiving])
#     - TD's (Expected TD's) (per game) (PFF [pff_receiving])
#     - Efficiency against Man (PFF [pff_man_zone])
#     - Efficiency against Zone (PFF [pff_man_zone])
#     - Average Seperation/Cushion? (Next Gen Stats Don't think you can download)
#     - Average Depth of Target (PFF [pff_receiving])
#     - % Slot/Outside (PFF [pff_receiving])
#     - Number/% of Snaps (PFF [pff_receiving])
#     - Position in Depth Chart
#     - RECV (PFF [pff_receiving])
#     - Yards / Routes Run (PFF [pff_receiving])
#     - Routes Run per game
#     - Consistency week - week
#     - Fantasy points trending  (maybe last couple games or something?)
#     - Year over year PPR / G change
#
#
# - Last year (new) team stats:
#     - Offense rating (PFR [pfr_tm_off])
#     - Pass Volume (PFR [pfr_tm_off])
#     - QB Ranking (PFF [pff_qb])
#     - O-Line Pass Block Ranking (PFF [pff_ol_pass])
#     - Time of Possession
#
# - This year personal stats:
#     - Age/Experience (Age is in PFR [pfr_fp])
#     - Position in Depth Chart
#     -  SOS? [pfr_sos]
#
# - Overall Status
#     - % increase/decrease in PPG from last year (Need to calculate)
#
# - This year team stats:
#     - Vacant Target Share

# %% [markdown]
# Reading in pff_receiving data

# %%
import pandas as pd

# Reading in pff_receiving data

pr14_15 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_14-15.csv')
pr15_16 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_15-16.csv')
pr16_17 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_16-17.csv')
pr17_18 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_17-18.csv')
pr18_19 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_18-19.csv')
pr19_20 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_19-20.csv')
pr20_21 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_20-21.csv')
pr21_22 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_21-22.csv')
pr22_23 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_22-23.csv')
pr23_24 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_23-24.csv')
pr24_25 = pd.read_csv('../fantasy_data/pff_receiving/pff_receiving_24-25.csv')

# Creating a season column to differentiate between seasons

pr14_15['Season'] = '2014-15'
pr15_16['Season'] = '2015-16'
pr16_17['Season'] = '2016-17'
pr17_18['Season'] = '2017-18'
pr18_19['Season'] = '2018-19'
pr19_20['Season'] = '2019-20'
pr20_21['Season'] = '2020-21'
pr21_22['Season'] = '2021-22'
pr22_23['Season'] = '2022-23'
pr23_24['Season'] = '2023-24'
pr24_25['Season'] = '2024-25'

# Combining all of the different season's data into one pff_receiving dataset

pff_receiving = pd.concat([pr14_15, pr15_16, pr16_17, pr17_18, pr18_19, pr19_20, pr20_21, pr21_22, pr22_23, pr23_24, pr24_25])

# Filter on only Wide Recievers

pff_receiving = pff_receiving[pff_receiving['position'] == 'WR']

pff_receiving
# Out:
#                player  player_id position team_name  player_game_count  \
# 0       Antonio Brown       5718       WR       PIT                 16
# 1    Demaryius Thomas       5547       WR       DEN                 16
# 2         Julio Jones       6158       WR       ATL                 15
# 3        Jordy Nelson       4350       WR        GB                 16
# 4     Kelvin Benjamin       8663       WR       CAR                 16
# ..                ...        ...      ...       ...                ...
# 480     Anthony Gould      97078       WR       IND                  3
# 481       Tom Kennedy      94379       WR       DET                  2
# 482   Brycen Tremayne      84425       WR       WAS                  2
# 486       Tyler Scott     123578       WR       CHI                  4
# 489       Justyn Ross      78021       WR        KC                  2
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# ...

# %% [markdown]
# Reading in the pff_man_zone data

# %%
pmz14_15 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_14-15.csv')
pmz15_16 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_15-16.csv')
pmz16_17 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_16-17.csv')
pmz17_18 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_17-18.csv')
pmz18_19 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_18-19.csv')
pmz19_20 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_19-20.csv')
pmz20_21 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_20-21.csv')
pmz21_22 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_21-22.csv')
pmz22_23 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_22-23.csv')
pmz23_24 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_23-24.csv')
pmz24_25 = pd.read_csv('../fantasy_data/pff_man_zone/pff_man_zone_24-25.csv')

pmz14_15['Season'] = '2014-15'
pmz15_16['Season'] = '2015-16'
pmz16_17['Season'] = '2016-17'
pmz17_18['Season'] = '2017-18'
pmz18_19['Season'] = '2018-19'
pmz19_20['Season'] = '2019-20'
pmz20_21['Season'] = '2020-21'
pmz21_22['Season'] = '2021-22'
pmz22_23['Season'] = '2022-23'
pmz23_24['Season'] = '2023-24'
pmz24_25['Season'] = '2024-25'

pff_man_zone = pd.concat([pmz14_15, pmz15_16, pmz16_17, pmz17_18, pmz18_19, pmz19_20, pmz20_21, pmz21_22, pmz22_23, pmz23_24, pmz24_25])

pff_man_zone = pff_man_zone[pff_man_zone['position'] == 'WR']

pff_man_zone
# Out:
#                player  player_id position team_name  player_game_count  \
# 0       Antonio Brown       5718       WR       PIT                 16
# 1    Demaryius Thomas       5547       WR       DEN                 16
# 2         Julio Jones       6158       WR       ATL                 15
# 3        Jordy Nelson       4350       WR        GB                 16
# 4     Kelvin Benjamin       8663       WR       CAR                 16
# ..                ...        ...      ...       ...                ...
# 480     Anthony Gould      97078       WR       IND                  3
# 481       Tom Kennedy      94379       WR       DET                  2
# 482   Brycen Tremayne      84425       WR       WAS                  2
# 486       Tyler Scott     123578       WR       CHI                  4
# 489       Justyn Ross      78021       WR        KC                  2
#
#      base_targets  declined_penalties  franchise_id  man_avg_depth_of_target  \
# ...

# %% [markdown]
# Reading in pfr_rz_rec data

# %%
pfr_rz_rec_14_15 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_14-15.csv')
pfr_rz_rec_15_16 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_15-16.csv')
pfr_rz_rec_16_17 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_16-17.csv')
pfr_rz_rec_17_18 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_17-18.csv')
pfr_rz_rec_18_19 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_18-19.csv')
pfr_rz_rec_19_20 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_19-20.csv')
pfr_rz_rec_20_21 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_20-21.csv')
pfr_rz_rec_21_22 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_21-22.csv')
pfr_rz_rec_22_23 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_22-23.csv')
pfr_rz_rec_23_24 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_23-24.csv')
pfr_rz_rec_24_25 = pd.read_csv('../fantasy_data/pfr_rz_rec/pfr_rz_rec_24-25.csv')

pfr_rz_rec_14_15['Season'] = '2014-15'
pfr_rz_rec_15_16['Season'] = '2015-16'
pfr_rz_rec_16_17['Season'] = '2016-17'
pfr_rz_rec_17_18['Season'] = '2017-18'
pfr_rz_rec_18_19['Season'] = '2018-19'
pfr_rz_rec_19_20['Season'] = '2019-20'
pfr_rz_rec_20_21['Season'] = '2020-21'
pfr_rz_rec_21_22['Season'] = '2021-22'
pfr_rz_rec_22_23['Season'] = '2022-23'
pfr_rz_rec_23_24['Season'] = '2023-24'
pfr_rz_rec_24_25['Season'] = '2024-25'

pfr_rz_rec = pd.concat([pfr_rz_rec_14_15, pfr_rz_rec_15_16, pfr_rz_rec_16_17, pfr_rz_rec_17_18, pfr_rz_rec_18_19, pfr_rz_rec_19_20, pfr_rz_rec_20_21, pfr_rz_rec_21_22, pfr_rz_rec_22_23, pfr_rz_rec_23_24, pfr_rz_rec_24_25])

pfr_rz_rec
# Out:
#                Player   Tm  Tgt20  Rec20  Ctch%20  Yds20  TD20  %Tgt20  Tgt10  \
# 0    Demaryius Thomas  DEN     39     18   46.15%    137     6  36.80%     18
# 1       Antonio Brown  PIT     33     18   54.55%    133     8  36.70%     18
# 2       Andre Johnson  HOU     26     12   46.15%     54     3  38.80%     11
# 3       Odell Beckham  NYG     25     16   64.00%    122     8  25.50%     10
# 4        Randall Cobb  GNB     25     16   64.00%     94    10  26.00%     14
# ..                ...  ...    ...    ...      ...    ...   ...     ...    ...
# 358      Blake Watson  DEN      1      1  100.00%     13     0    1.5%      0
# 359   Jamaal Williams  NOR      1      0    0.00%      0     0    2.6%      0
# 360    Cedrick Wilson  NOR      1      1  100.00%     12     1    2.6%      0
# 361     Jaylen Wright  MIA      1      1  100.00%      0     0    1.2%      1
# 362      Kenny Yeboah  NYJ      1      1  100.00%     11     1    1.2%      0
#
# ...

# %% [markdown]
# Reading in pfr_fp data

# %%
pfr_fp14_15 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_14-15.csv')
pfr_fp15_16 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_15-16.csv')
pfr_fp16_17 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_16-17.csv')
pfr_fp17_18 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_17-18.csv')
pfr_fp18_19 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_18-19.csv')
pfr_fp19_20 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_19-20.csv')
pfr_fp20_21 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_20-21.csv')
pfr_fp21_22 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_21-22.csv')
pfr_fp22_23 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_22-23.csv')
pfr_fp23_24 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_23-24.csv')
pfr_fp24_25 = pd.read_csv('../fantasy_data/pfr_fp/pfr_fp_24-25.csv')

pfr_fp14_15['Season'] = '2014-15'
pfr_fp15_16['Season'] = '2015-16'
pfr_fp16_17['Season'] = '2016-17'
pfr_fp17_18['Season'] = '2017-18'
pfr_fp18_19['Season'] = '2018-19'
pfr_fp19_20['Season'] = '2019-20'
pfr_fp20_21['Season'] = '2020-21'
pfr_fp21_22['Season'] = '2021-22'
pfr_fp22_23['Season'] = '2022-23'
pfr_fp23_24['Season'] = '2023-24'
pfr_fp24_25['Season'] = '2024-25'

pfr_fp = pd.concat([pfr_fp14_15, pfr_fp15_16, pfr_fp16_17, pfr_fp17_18, pfr_fp18_19, pfr_fp19_20, pfr_fp20_21, pfr_fp21_22, pfr_fp22_23, pfr_fp23_24, pfr_fp24_25])

# Getting rid of punctuation that sometimes trails player name in pfr data
pfr_fp['Player'] = pfr_fp['Player'].str.replace('[*+]', '', regex=True)

pfr_fp = pfr_fp[pfr_fp['FantPos'] == 'WR']

pfr_fp
# Out:
#       Rk             Player   Tm FantPos  Age   G  GS  Cmp  Att   Yds  ...  \
# 3      4      Antonio Brown  PIT      WR   26  16  16  2.0  2.0  20.0  ...
# 7      8   Demaryius Thomas  DEN      WR   27  16  16  0.0  0.0   0.0  ...
# 8      9       Jordy Nelson  GNB      WR   29  16  16  0.0  0.0   0.0  ...
# 9     10         Dez Bryant  DAL      WR   26  16  16  0.0  0.0   0.0  ...
# 14    15  Odell Beckham Jr.  NYG      WR   22  12  11  0.0  1.0   0.0  ...
# ..   ...                ...  ...     ...  ...  ..  ..  ...  ...   ...  ...
# 621  622       Roman Wilson  PIT      WR   23   1   0  0.0  0.0   0.0  ...
# 623  624       Dareke Young  SEA      WR   25  14   0  0.0  0.0   0.0  ...
# 626  627        Steven Sims  2TM      WR   27   9   0  0.0  0.0   0.0  ...
# 627  628     Kadarius Toney  CLE      WR   25   3   0  0.0  0.0   0.0  ...
# 629  630   Jha'Quan Jackson  TEN      WR   24  12   0  0.0  0.0   0.0  ...
#
# ...

# %% [markdown]
# Reading in pfr_tm_off data

# %%
pfr_tm_off_14_15 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_14-15.csv')
pfr_tm_off_15_16 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_15-16.csv')
pfr_tm_off_16_17 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_16-17.csv')
pfr_tm_off_17_18 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_17-18.csv')
pfr_tm_off_18_19 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_18-19.csv')
pfr_tm_off_19_20 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_19-20.csv')
pfr_tm_off_20_21 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_20-21.csv')
pfr_tm_off_21_22 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_21-22.csv')
pfr_tm_off_22_23 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_22-23.csv')
pfr_tm_off_23_24 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_23-24.csv')
pfr_tm_off_24_25 = pd.read_csv('../fantasy_data/pfr_tm_off/pfr_tm_off_24-25.csv')

pfr_tm_off_14_15['Season'] = '2014-15'
pfr_tm_off_15_16['Season'] = '2015-16'
pfr_tm_off_16_17['Season'] = '2016-17'
pfr_tm_off_17_18['Season'] = '2017-18'
pfr_tm_off_18_19['Season'] = '2018-19'
pfr_tm_off_19_20['Season'] = '2019-20'
pfr_tm_off_20_21['Season'] = '2020-21'
pfr_tm_off_21_22['Season'] = '2021-22'
pfr_tm_off_22_23['Season'] = '2022-23'
pfr_tm_off_23_24['Season'] = '2023-24'
pfr_tm_off_24_25['Season'] = '2024-25'

pfr_tm_off = pd.concat([pfr_tm_off_14_15, pfr_tm_off_15_16, pfr_tm_off_16_17, pfr_tm_off_17_18, pfr_tm_off_18_19, pfr_tm_off_19_20, pfr_tm_off_20_21, pfr_tm_off_21_22, pfr_tm_off_22_23, pfr_tm_off_23_24, pfr_tm_off_24_25])

# Getting rid of statistical summary rows that exist amongst the individual team stats
pfr_tm_off = pfr_tm_off[~pfr_tm_off['Tm'].isin(['Avg Team', 'League Total', 'Avg Tm/G'])]

pfr_tm_off = pfr_tm_off.rename(columns={"G":"Team_G"})

pfr_tm_off
# Out:
#       Rk                    Tm  Team_G     PF  Tot_Yds  Tot_Ply  Y/P    TO  \
# 0    1.0     Green Bay Packers    16.0  486.0   6178.0   1001.0  6.2  13.0
# 1    2.0        Denver Broncos    16.0  482.0   6446.0   1067.0  6.0  20.0
# 2    3.0   Philadelphia Eagles    16.0  474.0   6348.0   1127.0  5.6  36.0
# 3    4.0  New England Patriots    16.0  468.0   5848.0   1073.0  5.5  13.0
# 4    5.0        Dallas Cowboys    16.0  467.0   6138.0   1014.0  6.1  25.0
# ..   ...                   ...     ...    ...      ...      ...  ...   ...
# 27  28.0         Chicago Bears    17.0  310.0   4820.0   1065.0  4.5  16.0
# 28  29.0     Las Vegas Raiders    17.0  309.0   5154.0   1065.0  4.8  29.0
# 29  30.0  New England Patriots    17.0  289.0   4964.0   1027.0  4.8  23.0
# 30  31.0       New York Giants    17.0  273.0   5011.0   1063.0  4.7  23.0
# 31  32.0      Cleveland Browns    17.0  258.0   5114.0   1118.0  4.6  34.0
#
# ...

# %% [markdown]
# Reading in pff_qb data, and the qb_depth_chart data. Joining them together to make pff_qb_starters.

# %%
pff_qb_14_15 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_14-15.csv')
pff_qb_15_16 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_15-16.csv')
pff_qb_16_17 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_16-17.csv')
pff_qb_17_18 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_17-18.csv')
pff_qb_18_19 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_18-19.csv')
pff_qb_19_20 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_19-20.csv')
pff_qb_20_21 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_20-21.csv')
pff_qb_21_22 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_21-22.csv')
pff_qb_22_23 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_22-23.csv')
pff_qb_23_24 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_23-24.csv')
pff_qb_24_25 = pd.read_csv('../fantasy_data/pff_qb/pff_qb_24-25.csv')

pff_qb_14_15['Season'] = '2014-15'
pff_qb_15_16['Season'] = '2015-16'
pff_qb_16_17['Season'] = '2016-17'
pff_qb_17_18['Season'] = '2017-18'
pff_qb_18_19['Season'] = '2018-19'
pff_qb_19_20['Season'] = '2019-20'
pff_qb_20_21['Season'] = '2020-21'
pff_qb_21_22['Season'] = '2021-22'
pff_qb_22_23['Season'] = '2022-23'
pff_qb_23_24['Season'] = '2023-24'
pff_qb_24_25['Season'] = '2024-25'

pff_qb = pd.concat([pff_qb_14_15, pff_qb_15_16, pff_qb_16_17, pff_qb_17_18, pff_qb_18_19, pff_qb_19_20, pff_qb_20_21, pff_qb_21_22, pff_qb_22_23, pff_qb_23_24, pff_qb_24_25])

pff_qb = pff_qb[pff_qb['position'] == 'QB']

# Make a column for lowercase player name to join with our depth chart scraped data

pff_qb['lower_name'] = pff_qb['player'].apply(lambda x: x.lower() if isinstance(x, str) else x)

# Rename the player_id column to qb_id

pff_qb = pff_qb.rename(columns={"player_id": "qb_id", "player":"qb"})

# Read in qb_depth_chart data

qb_depth_chart = pd.read_csv('../qb_models/qb_depth_chart.csv')

# Merge pff_qb with qb_depth_chart

pff_qb_starters = pd.merge(left=qb_depth_chart, right=pff_qb, how='left', left_on=['Season', 'Name'], right_on=['Season', 'lower_name'])

# Using qb_depth_chart's Team for merging, not pff_qb's

pff_qb = pff_qb.drop(columns=['team_name'])
pff_qb_starters = pff_qb_starters.drop(columns=['team_name'])

# Change team names in Depth Chart data to the standard 
depth_chart_key = {'ARZ':'ARI'}

pff_qb_starters['Team'] = pff_qb_starters['Team'].replace(depth_chart_key)


pff_qb_starters
# Out:
#     Team   Season                Name                  qb     qb_id position  \
# 0    ARI  2024-25        kyler murray        Kyler Murray   38334.0       QB
# 1    ATL  2024-25        kirk cousins        Kirk Cousins    7102.0       QB
# 2    BAL  2024-25       lamar jackson       Lamar Jackson   46416.0       QB
# 3    BUF  2024-25          josh allen          Josh Allen   46601.0       QB
# 4    CAR  2024-25         bryce young         Bryce Young  123943.0       QB
# ..   ...      ...                 ...                 ...       ...      ...
# 347  SEA  2014-15      russell wilson      Russell Wilson    7077.0       QB
# 348   SF  2014-15    colin kaepernick    Colin Kaepernick    6188.0       QB
# 349   TB  2014-15         josh mccown         Josh McCown    1085.0       QB
# 350  TEN  2014-15         jake locker         Jake Locker    6160.0       QB
# 351  WAS  2014-15  robert griffin iii  Robert Griffin III    7008.0       QB
#
# ...

# %% [markdown]
# Reading in pff_ol_pass data

# %%
pff_ol_pass_14_15 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_14-15.csv')
pff_ol_pass_15_16 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_15-16.csv')
pff_ol_pass_16_17 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_16-17.csv')
pff_ol_pass_17_18 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_17-18.csv')
pff_ol_pass_18_19 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_18-19.csv')
pff_ol_pass_19_20 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_19-20.csv')
pff_ol_pass_20_21 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_20-21.csv')
pff_ol_pass_21_22 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_21-22.csv')
pff_ol_pass_22_23 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_22-23.csv')
pff_ol_pass_23_24 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_23-24.csv')
pff_ol_pass_24_25 = pd.read_csv('../fantasy_data/pff_ol_pass/pff_ol_pass_24-25.csv')

pff_ol_pass_14_15['Season'] = '2014-15'
pff_ol_pass_15_16['Season'] = '2015-16'
pff_ol_pass_16_17['Season'] = '2016-17'
pff_ol_pass_17_18['Season'] = '2017-18'
pff_ol_pass_18_19['Season'] = '2018-19'
pff_ol_pass_19_20['Season'] = '2019-20'
pff_ol_pass_20_21['Season'] = '2020-21'
pff_ol_pass_21_22['Season'] = '2021-22'
pff_ol_pass_22_23['Season'] = '2022-23'
pff_ol_pass_23_24['Season'] = '2023-24'
pff_ol_pass_24_25['Season'] = '2024-25'

pff_ol_pass = pd.concat([pff_ol_pass_14_15, pff_ol_pass_15_16, pff_ol_pass_16_17, pff_ol_pass_17_18, pff_ol_pass_18_19, pff_ol_pass_19_20, pff_ol_pass_20_21, pff_ol_pass_21_22, pff_ol_pass_22_23, pff_ol_pass_23_24, pff_ol_pass_24_25])

pff_ol_pass
# Out:
#    team_name  franchise_id  player_game_count  attempts  hits_allowed  \
# 0        DEN            10                 16       624            25
# 1        CIN             7                 16       545            21
# 2         GB            12                 16       595            18
# 3        DAL             9                 16       517            17
# 4        BLT             3                 16       576            21
# ..       ...           ...                ...       ...           ...
# 27       MIN            18                 17       626            24
# 28       TEN            31                 17       616            35
# 29       NYG            21                 17       670            47
# 30       SEA            29                 17       670            32
# 31        NE            19                 17       641            37
#
#     hurries_allowed  pass_snaps   pbe  pressures_allowed  sacks_allowed  \
# ...

# %% [markdown]
# Reading in pfr_tm_def and pfr_schedule to make pfr_sos

# %%
pfr_tm_def_14_15 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_14-15.csv')
pfr_tm_def_15_16 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_15-16.csv')
pfr_tm_def_16_17 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_16-17.csv')
pfr_tm_def_17_18 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_17-18.csv')
pfr_tm_def_18_19 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_18-19.csv')
pfr_tm_def_19_20 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_19-20.csv')
pfr_tm_def_20_21 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_20-21.csv')
pfr_tm_def_21_22 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_21-22.csv')
pfr_tm_def_22_23 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_22-23.csv')
pfr_tm_def_23_24 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_23-24.csv')
pfr_tm_def_24_25 = pd.read_csv('../fantasy_data/pfr_tm_def/pfr_tm_def_24-25.csv')

pfr_tm_def_14_15['Season'] = '2014-15'
pfr_tm_def_15_16['Season'] = '2015-16'
pfr_tm_def_16_17['Season'] = '2016-17'
pfr_tm_def_17_18['Season'] = '2017-18'
pfr_tm_def_18_19['Season'] = '2018-19'
pfr_tm_def_19_20['Season'] = '2019-20'
pfr_tm_def_20_21['Season'] = '2020-21'
pfr_tm_def_21_22['Season'] = '2021-22'
pfr_tm_def_22_23['Season'] = '2022-23'
pfr_tm_def_23_24['Season'] = '2023-24'
pfr_tm_def_24_25['Season'] = '2024-25'

pfr_tm_def = pd.concat([pfr_tm_def_14_15, pfr_tm_def_15_16, pfr_tm_def_16_17, pfr_tm_def_17_18, pfr_tm_def_18_19, pfr_tm_def_19_20, pfr_tm_def_20_21, pfr_tm_def_21_22, pfr_tm_def_22_23, pfr_tm_def_23_24, pfr_tm_def_24_25])

# Getting rid of statistical summary rows that exist amongst the individual team stats
pfr_tm_def = pfr_tm_def[~pfr_tm_def['Tm'].isin(['Avg Team', 'League Total', 'Avg Tm/G'])]

pfr_schedule_14_15 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_14-15.csv')
pfr_schedule_15_16 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_15-16.csv')
pfr_schedule_16_17 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_16-17.csv')
pfr_schedule_17_18 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_17-18.csv')
pfr_schedule_18_19 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_18-19.csv')
pfr_schedule_19_20 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_19-20.csv')
pfr_schedule_20_21 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_20-21.csv')
pfr_schedule_21_22 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_21-22.csv')
pfr_schedule_22_23 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_22-23.csv')
pfr_schedule_23_24 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_23-24.csv')
pfr_schedule_24_25 = pd.read_csv('../fantasy_data/pfr_schedule/pfr_schedule_24-25.csv')

pfr_schedule_14_15['Season'] = '2014-15'
pfr_schedule_15_16['Season'] = '2015-16'
pfr_schedule_16_17['Season'] = '2016-17'
pfr_schedule_17_18['Season'] = '2017-18'
pfr_schedule_18_19['Season'] = '2018-19'
pfr_schedule_19_20['Season'] = '2019-20'
pfr_schedule_20_21['Season'] = '2020-21'
pfr_schedule_21_22['Season'] = '2021-22'
pfr_schedule_22_23['Season'] = '2022-23'
pfr_schedule_23_24['Season'] = '2023-24'
pfr_schedule_24_25['Season'] = '2024-25'

pfr_schedule = pd.concat([pfr_schedule_14_15, pfr_schedule_15_16, pfr_schedule_16_17, pfr_schedule_17_18, pfr_schedule_18_19, pfr_schedule_19_20, pfr_schedule_20_21, pfr_schedule_21_22, pfr_schedule_22_23, pfr_schedule_23_24, pfr_schedule_24_25])

pfr_schedule = pfr_schedule[~pfr_schedule['Week'].isin(['WildCard', 'Division', 'ConfChamp', 'SuperBowl'])]

# PFR Full Name -> Standard
pfr_team_name_key = {'Arizona Cardinals':'ARI', 'Atlanta Falcons':'ATL', 'Baltimore Ravens': 'BAL', 'Buffalo Bills': 'BUF', 'Carolina Panthers':'CAR',
                      'Chicago Bears':'CHI', 'Cincinnati Bengals':'CIN', 'Cleveland Browns':'CLE', 'Dallas Cowboys':'DAL', 'Denver Broncos':'DEN', 
                      'Detroit Lions': 'DET', 'Green Bay Packers':'GB', 'Houston Texans':'HOU', 'Indianapolis Colts':'IND', 'Jacksonville Jaguars':'JAX', 
                      'Kansas City Chiefs':'KC', 'Miami Dolphins':'MIA', 'Minnesota Vikings':'MIN', 'New England Patriots':'NE','New Orleans Saints':'NO', 
                      'New York Giants':'NYG', 'New York Jets':'NYJ', 'Oakland Raiders':'LV', 'Las Vegas Raiders':'LV', 'Philadelphia Eagles':'PHI', 
                      'Pittsburgh Steelers':'PIT', 'San Diego Chargers':'LAC', 'Los Angeles Chargers':'LAC', 'San Francisco 49ers':'SF', 'Seattle Seahawks':'SEA', 
                      'St. Louis Rams':'LAR', 'Los Angeles Rams':'LAR', 'Tampa Bay Buccaneers':'TB', 'Tennessee Titans':'TEN', 'Washington Redskins':'WAS', 
                      'Washington Commanders':'WAS', 'Washington Football Team':'WAS'}


for key in pfr_team_name_key:
    pfr_tm_def = pfr_tm_def.replace(key, pfr_team_name_key[key])
    pfr_schedule = pfr_schedule.replace(key, pfr_team_name_key[key])


teams = pfr_tm_def['Tm'].unique()
seasons = pfr_tm_def['Season'].unique()

# Creating rankings for best team run defenses

pfr_tm_def['rec_def_points'] = pfr_tm_def['Pass_Cmp'] + (pfr_tm_def['Pass_Yds'] / 10) + (pfr_tm_def['Pass_TD'] * 6)

# Points Allowed Ranking
for season in seasons:
    pfr_tm_def_season = pfr_tm_def[pfr_tm_def['Season'] == season]
    pfr_tm_def_season['points_allowed_rank'] = pfr_tm_def_season['PA'].rank(ascending=True, method='min')
    pfr_tm_def.loc[pfr_tm_def['Season'] == season, 'points_allowed_rank'] = pfr_tm_def_season['points_allowed_rank'].values
    pfr_tm_def_season['rec_def_rank'] = pfr_tm_def_season['rec_def_points'].rank(ascending=True, method='min')
    pfr_tm_def.loc[pfr_tm_def['Season'] == season, 'rec_def_rank'] = pfr_tm_def_season['rec_def_rank'].values


# Aggregating team schedules for each season and calculating average opponent defense rankings
pfr_sos = []
for season in seasons:
    for team in teams:
        wins = pfr_schedule.loc[(pfr_schedule['Winner/tie'] == team) & (pfr_schedule['Season'] == season), ['Winner/tie', 'Loser/tie', 'Season']]
        losses = pfr_schedule.loc[(pfr_schedule['Loser/tie'] == team) & (pfr_schedule['Season'] == season), ['Winner/tie', 'Loser/tie', 'Season']]
        opponents = []
        opponents.extend(wins['Loser/tie'].tolist())
        opponents.extend(losses['Winner/tie'].tolist())
        average_opponent_def_rank = []
        average_opponent_rec_def_rank = []
        for opponent in opponents:
            average_opponent_def_rank.append(pfr_tm_def[(pfr_tm_def['Tm'] == opponent) & (pfr_tm_def['Season'] == season)]['points_allowed_rank'].item())
            average_opponent_rec_def_rank.append(pfr_tm_def[(pfr_tm_def['Tm'] == opponent) & (pfr_tm_def['Season'] == season)]['rec_def_rank'].item())
        
        pfr_sos.append({
            'Tm': team,
            'Season': season,
            'average_opponent_def_rank': sum(average_opponent_def_rank) / len(average_opponent_def_rank),
            'average_opponent_rec_def_rank': sum(average_opponent_rec_def_rank) / len(average_opponent_rec_def_rank)
        })
        
pfr_sos = pd.DataFrame(pfr_sos)

pfr_sos
# Out:
# C:\Users\scott\AppData\Local\Temp\ipykernel_22456\2171417939.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pfr_tm_def_season['points_allowed_rank'] = pfr_tm_def_season['PA'].rank(ascending=True, method='min')
# C:\Users\scott\AppData\Local\Temp\ipykernel_22456\2171417939.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pfr_tm_def_season['rec_def_rank'] = pfr_tm_def_season['rec_def_points'].rank(ascending=True, method='min')
# ...

# %% [markdown]
# Feature Selection

# %%
pff_receiving_final = pff_receiving[['player', 'player_id', 'Season', 'position', 'team_name', 'player_game_count', 'avg_depth_of_target', 'caught_percent', 'franchise_id', 'grades_offense', 'grades_pass_route', 'pass_plays', 'receptions', 'route_rate', 'routes', 'slot_rate', 'targets', 'touchdowns', 'yards', 'wide_rate', 'inline_rate', 'yards_after_catch', 'yprr']]

pff_man_zone_final = pff_man_zone[['player', 'player_id', 'Season', 'position', 'team_name', 'franchise_id', 'man_grades_pass_route', 'zone_grades_pass_route']]

pfr_fp_final = pfr_fp[['Player', 'Tm', 'Season', 'Age', 'FantPos', 'G', 'GS', 'PPR', 'PosRank', '-9999']]

pfr_fp_prev = pfr_fp[['PPR', 'Season', '-9999', 'G']]

pfr_fp_prev2 = pfr_fp[['PPR', 'Season', '-9999', 'G']]

pfr_rz_rec_final = pfr_rz_rec[['Player', 'Tm', 'Season', 'Tgt20']]

pfr_tm_off_final = pfr_tm_off[['Tm', 'Team_G', 'Season', 'P_Att', 'P_Yds', 'P_TD', 'P_Cmp']]

pff_qb_final = pff_qb[['qb', 'qb_id','Season','grades_pass']]

pff_qb_starters_final = pff_qb_starters[['qb', 'qb_id', 'Team', 'Season']]

pff_ol_pass_final = pff_ol_pass[['team_name', 'Season', 'pbe']]

# %% [markdown]
# Preparing data to be merged

# %%
# Let's make Team Abbreviation Standard
# ARI | ATL | BAL | BUF | CAR | CHI | CIN | CLE | DAL | DEN | DET | GB | HOU | IND | JAX | KC
# LAC (SD) | LAR (SL) | LV (OAK) | MIA | MIN | NE | NO | NYG | NYJ | PHI | PIT | SEA | SF | TB | TEN | WAS

# PFF -> Standard
pff_team_key = {'ARZ': 'ARI', 'BLT': 'BAL', 'CLV': 'CLE', 'HST': 'HOU', 'LA': 'LAR', 'OAK': 'LV', 'SL': 'LAR', 'SD':'LAC'}
# PFR Abreviation -> Standard
pfr_team_abv_key = {'GNB':'GB', 'KAN':'KC', 'LVR':'LV', 'NWE':'NE', 'NOR':'NO', 'OAK':'LV', 'SDG':'LAC', 'SFO':'SF', 'STL':'LAR', 'TAM':'TB'}
# PFR Full Name -> Standard
pfr_team_name_key = {'Arizona Cardinals':'ARI', 'Atlanta Falcons':'ATL', 'Baltimore Ravens': 'BAL', 'Buffalo Bills': 'BUF', 'Carolina Panthers':'CAR',
                      'Chicago Bears':'CHI', 'Cincinnati Bengals':'CIN', 'Cleveland Browns':'CLE', 'Dallas Cowboys':'DAL', 'Denver Broncos':'DEN', 
                      'Detroit Lions': 'DET', 'Green Bay Packers':'GB', 'Houston Texans':'HOU', 'Indianapolis Colts':'IND', 'Jacksonville Jaguars':'JAX', 
                      'Kansas City Chiefs':'KC', 'Miami Dolphins':'MIA', 'Minnesota Vikings':'MIN', 'New England Patriots':'NE','New Orleans Saints':'NO', 
                      'New York Giants':'NYG', 'New York Jets':'NYJ', 'Oakland Raiders':'LV', 'Las Vegas Raiders':'LV', 'Philadelphia Eagles':'PHI', 
                      'Pittsburgh Steelers':'PIT', 'San Diego Chargers':'LAC', 'Los Angeles Chargers':'LAC', 'San Francisco 49ers':'SF', 'Seattle Seahawks':'SEA', 
                      'St. Louis Rams':'LAR', 'Los Angeles Rams':'LAR', 'Tampa Bay Buccaneers':'TB', 'Tennessee Titans':'TEN', 'Washington Redskins':'WAS', 
                      'Washington Commanders':'WAS', 'Washington Football Team':'WAS'}

for key in pff_team_key:
    pff_receiving_final = pff_receiving_final.replace(key, pff_team_key[key])
    pff_man_zone_final = pff_man_zone_final.replace(key, pff_team_key[key])
    pff_ol_pass_final = pff_ol_pass_final.replace(key, pff_team_key[key])

for key in pfr_team_abv_key:
    pfr_fp_final = pfr_fp_final.replace(key, pfr_team_abv_key[key])
    pfr_rz_rec_final = pfr_rz_rec_final.replace(key, pfr_team_abv_key[key])

for key in pfr_team_name_key:
    pfr_tm_off_final = pfr_tm_off_final.replace(key, pfr_team_name_key[key])


# Some players have different names between different files, which unfortunately is what I have to go off of.
# I am changing the PFR names to reflect the PFF names

name_key = {"John Metchie":"John Metchie III", "Calvin Austin":"Calvin Austin III", "Marvin Mims": "Marvin Mims Jr.", "Easop Winston": "Easop Winston Jr.", 
            "David Sills": "David Sills V", "Josh Palmer": "Joshua Palmer", "James Proche": "James Proche II", "Terry Godwin":"Terry Godwin II", "DeMichael Harris": "De'Michael Harris",
            "Lynn Bowden Jr.": "Lynn Bowden", "Gabriel Davis": "Gabe Davis", "Steven Mitchell": "Steven Mitchell Jr.", "Stanley Morgan Jr.": "Stanley Morgan", 
            "JJ Arcega-Whiteside":"J.J. Arcega-Whiteside", "Mecole Hardman":"Mecole Hardman Jr.", "JJ Jones": "J.J. Jones", "Victor Bolden": "Victor Bolden Jr.",
            "Ray-Ray McCloud": "Ray-Ray McCloud III", "DJ Chark":"DJ Chark Jr.", "D.J. Moore":"DJ Moore", "Jojo Natson":"JoJo Natson", "Keelan Cole":"Keelan Cole Sr.",
            "Jakeem Grant":"Jakeem Grant Sr.", "Demarcus Ayers":"De'Marcus Ayers", "Roger Lewis":"Roger Lewis Jr.", "Walt Powell":"Walter Powell", "Will Fuller":"Will Fuller V",
            "Chris Harper":"Christopher Harper", "Terrelle Pryor":"Terrelle Pryor Sr.", "JJ Nelson":"J.J. Nelson", "Donteea Dye":"Donteea Dye Jr.", "Rashad Greene":"Rashad Greene Sr.",
            "Steve Smith Sr.":"Steve Smith", "Marvin Jones":"Marvin Jones Jr.", "Willie Snead":"Willie Snead IV", "Josh Cribbs":"Joshua Cribbs", "De'Andre Presley": "DeAndre Presley", 
            "Paul Richardson":"Paul Richardson Jr.", "Stevie Johnson": "Steve Johnson", "Louis Murphy": "Louis Murphy Jr.", "Allen Robinson": "Allen Robinson II", 
            "Odell Beckham": "Odell Beckham Jr.", "Michael Pittman": "Michael Pittman Jr."}
for key in name_key:
    pfr_fp_final = pfr_fp_final.replace(key, name_key[key])
    pfr_rz_rec_final = pfr_rz_rec_final.replace(key, name_key[key])

# In PFR, some people are noted as being on 2TM or 3TM or 4TM. Here we will take a subset of those players,
# and then merge them later to the data without using team as a key

pfr_rz_rec_mult_tms = pfr_rz_rec_final[pfr_rz_rec_final['Tm'].isin(['2TM', '3TM', '4TM'])]

print(pfr_tm_off_final)
# Out:
#      Tm  Team_G   Season  P_Att   P_Yds  P_TD  P_Cmp
# 0    GB    16.0  2014-15  536.0  4261.0  38.0  349.0
# 1   DEN    16.0  2014-15  607.0  4661.0  40.0  399.0
# 2   PHI    16.0  2014-15  621.0  4356.0  27.0  384.0
# 3    NE    16.0  2014-15  609.0  4121.0  34.0  392.0
# 4   DAL    16.0  2014-15  476.0  3784.0  37.0  328.0
# ..  ...     ...      ...    ...     ...   ...    ...
# 27  CHI    17.0  2024-25  566.0  3086.0  20.0  353.0
# 28   LV    17.0  2024-25  635.0  3797.0  19.0  410.0
# 29   NE    17.0  2024-25  529.0  2995.0  18.0  342.0
# 30  NYG    17.0  2024-25  591.0  3228.0  15.0  366.0
# 31  CLE    17.0  2024-25  661.0  3506.0  19.0  395.0
#
# [352 rows x 7 columns]

# %% [markdown]
# Creating df from pfr_fp_final, and adding on the previous 2 seasons of ppg data by joining back to itself

# %%
# Start off with pfr_fp_final without including the oldest year in the data

df = pfr_fp_final[pfr_fp_final['Season'] != '2014-15']

# Create column for prev_season

season_key = {'2024-25': '2023-24','2023-24': '2022-23', '2022-23':'2021-22', '2021-22':'2020-21', '2020-21':'2019-20', 
              '2019-20':'2018-19', '2018-19':'2017-18', '2017-18':'2016-17', '2016-17':'2015-16', 
              '2015-16':'2014-15'}

df['prev_season'] = df['Season'].map(season_key)

# Create column for prev_2_season

season_key = {'2024-25': '2022-23','2023-24': '2021-22', '2022-23':'2020-21', '2021-22':'2019-18', '2020-21':'2018-19', 
              '2019-20':'2017-18', '2018-19':'2016-17', '2017-18':'2015-16', '2016-17':'2014-15'}

df['prev_2_season'] = df['Season'].map(season_key)

# Joining df to previous season's pfr_fp_prev to get last season's PPR points

pfr_fp_prev['PPR/G_prev'] = pfr_fp_prev['PPR'] / pfr_fp_prev['G']
pfr_fp_prev = pfr_fp_prev[['PPR/G_prev', 'Season', '-9999']]

df = pd.merge(left=df, right=pfr_fp_prev, how='left', left_on=['-9999', 'prev_season'], right_on=['-9999', 'Season'], suffixes=[None, '_copy'])
df = df.drop(columns=['Season_copy'])

# Joining df to 2 season's ago pfr_fp_prev2 to get PPR points from 2 seasons ago

pfr_fp_prev2['PPR/G'] = pfr_fp_prev2['PPR'] / pfr_fp_prev2['G']
pfr_fp_prev2 = pfr_fp_prev2.rename(columns={"PPR/G":"PPR/G_prev2"})
pfr_fp_prev2 = pfr_fp_prev2[['PPR/G_prev2', 'Season', '-9999']]

df = pd.merge(left=df, right=pfr_fp_prev2, how='left', left_on=['-9999', 'prev_2_season'], right_on=['-9999', 'Season'], suffixes=[None, '_copy'])
df = df.drop(columns=['Season_copy'])
# Out:
# C:\Users\scott\AppData\Local\Temp\ipykernel_23228\37099900.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prev_season'] = df['Season'].map(season_key)
# C:\Users\scott\AppData\Local\Temp\ipykernel_23228\37099900.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prev_2_season'] = df['Season'].map(season_key)
# C:\Users\scott\AppData\Local\Temp\ipykernel_23228\37099900.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# Joining Tables Together

# %%
# Data Model
# pfr_fp (Currently in df): Fantasy Points from Current Year
# pff_receiving: Receiving Statistics from Previous Year
# pff_man_zone: Man/Zone Statistics from Previous Year
# pfr_rz_rec: Red Zone Statistics from Previous Year
# pfr_tm_off: Current Year team's Offensive Statistics from Previous Year
# pff_qb: Current Year team's pff_qb_starter Statistics from Previous Year
# pff_ol_pass: Current Year team's OL Statistics from Previous Year


# Joining df (which currently just has pfr data) with current season pff_receiving just to get player_id for future joins. This will only work
# for players that were on one team the whole season.

player_ids = pff_receiving_final[['player', 'player_id', 'Season', 'team_name']]
df = pd.merge(left=df, right=player_ids, how='left', left_on=['Player', 'Tm', 'Season'], right_on=['player', 'team_name', 'Season'], suffixes=[None, '_copy'])
df = df.drop(columns=['player', 'team_name'])

# Join df with current season pff_receiving data without using teams for players that were on multiple teams.
# This will fill in the player_id information for players that were on multiple teams and will do nothing for
# all other players.

df = pd.merge(left=df, right=player_ids, how='left', left_on=['Player', 'Season'], right_on=['player', 'Season'], suffixes=[None, '_copy'])
df['player_id'].fillna(df['player_id_copy'], inplace=True)
df = df.drop(columns=['player_id_copy', 'player', 'team_name'])

# Joining df with with pff_receiving data to get previous year's receiving data

df = pd.merge(left=df, right=pff_receiving_final, how='left', left_on=['player_id', 'prev_season'], right_on=['player_id', 'Season'], suffixes=[None,'_copy'])
df = df.drop(columns=['Season_copy'])
df = df.rename(columns={'team_name':'prev_team'})

# Joining df with pff_man_zone to get previous year's statistics against man and zone coverage

df = pd.merge(left=df, right=pff_man_zone_final, how='left', left_on=['player_id', 'prev_season'], right_on=['player_id', 'Season'], suffixes=[None, '_copy'])
df = df.drop(columns=['player_copy', 'Season_copy', 'position_copy', 'franchise_id_copy'])

# Joining df with pfr_rz_rec data to get previous year's redzone data

df = pd.merge(left=df, right=pfr_rz_rec_final, how='left', left_on=['Player', 'prev_team', 'prev_season'], right_on=['Player', 'Tm', 'Season'], suffixes=[None, '_copy'])
df = df.drop(columns=['Season_copy', 'Tm_copy'])

# Joining df with pfr_rz_rec_mult_tms to get previous year's redzone data for players on multiple teams, since pfr_rz unfortunately doesn't have a -9999 (pfr player id)
# field to join on

df = pd.merge(left=df, right=pfr_rz_rec_mult_tms, how='left', left_on=['Player', 'prev_season'], right_on=['Player', 'Season'], suffixes=[None, '_copy'])
df['Tgt20'].fillna(df['Tgt20_copy'], inplace=True)
df = df.drop(columns=['Tm_copy', 'Season_copy', 'Tgt20_copy'])

# Joining df with pff_qb_starters to find the starter you need

df = pd.merge(left=df, right=pff_qb_starters_final, how='left', left_on=['Tm', 'Season'], right_on=['Team', 'Season'], suffixes=[None, '_copy'])
df = df.drop(columns=['Team'])

# Joining df with pff_qb to get the grade of the current qb in the previous season

df = pd.merge(left=df, right=pff_qb_final, how='left', left_on=['qb_id', 'prev_season'], right_on=['qb_id', 'Season'], suffixes=[None, '_copy'])
df = df.drop(columns=['qb_copy', 'Season_copy'])

# Joining df with pff_ol_pass to get the grade of the current team offensive line's pass blocking in the previous season

df = pd.merge(left=df, right=pff_ol_pass_final, how='left', left_on=['Tm', 'prev_season'], right_on=['team_name', 'Season'], suffixes=[None, '_copy'])

# Joining df with pfr_tm_off to get statistics about the current team's offense from previous season

df = pd.merge(left=df, right=pfr_tm_off_final, how='left', left_on=['Tm', 'prev_season'], right_on=['Tm', 'Season'], suffixes=[None, '_copy'])
df = df.drop(columns=['Season_copy'])

df.to_csv('merged_wr_df.csv')
df
# Out:
#                  Player   Tm   Season  Age FantPos   G  GS    PPR  PosRank  \
# 0         Antonio Brown  PIT  2015-16   27      WR  16  16  388.2        1
# 1           Julio Jones  ATL  2015-16   26      WR  16  16  375.1        2
# 2      Brandon Marshall  NYJ  2015-16   31      WR  16  16  339.2        3
# 3     Allen Robinson II  JAX  2015-16   22      WR  16  16  304.0        4
# 4     Odell Beckham Jr.  NYG  2015-16   23      WR  15  15  319.3        5
# ...                 ...  ...      ...  ...     ...  ..  ..    ...      ...
# 2440       Roman Wilson  PIT  2024-25   23      WR   1   0    NaN      243
# 2441       Dareke Young  SEA  2024-25   25      WR  14   0    NaN      244
# 2442        Steven Sims  2TM  2024-25   27      WR   9   0   -2.0      248
# 2443     Kadarius Toney  CLE  2024-25   25      WR   3   0   -2.4      249
# 2444   Jha'Quan Jackson  TEN  2024-25   24      WR  12   0   -2.7      250
#
# ...

# %% [markdown]
# Calculate Variable to determine whether or not the WR is on an upward trend

# %%
df['Improvement'] = (df['PPR/G_prev'] - df['PPR/G_prev2']) / df['PPR/G_prev2']
df[df['Season'] == '2024-25'][['Player', 'Tm', 'Season', 'PPR/G_prev', 'PPR/G_prev2', 'Improvement']].head(25)
# Out:
#                    Player   Tm   Season  PPR/G_prev  PPR/G_prev2  Improvement
# 2194        Ja'Marr Chase  CIN  2024-25   16.418750    20.200000    -0.187191
# 2195     Justin Jefferson  MIN  2024-25   20.220000    21.688235    -0.067697
# 2196    Amon-Ra St. Brown  DET  2024-25   20.681250    16.725000     0.236547
# 2197         Brian Thomas  JAX  2024-25         NaN          NaN          NaN
# 2198       Terry McLaurin  WAS  2024-25   12.305882    13.470588    -0.086463
# 2199         Drake London  ATL  2024-25   10.900000    10.505882     0.037514
# 2200           Mike Evans   TB  2024-25   16.617647    15.026667     0.105877
# 2201         Malik Nabers  NYG  2024-25         NaN          NaN          NaN
# 2202          CeeDee Lamb  DAL  2024-25   23.717647    17.741176     0.336870
# 2203     Courtland Sutton  DEN  2024-25   11.887500    10.626667     0.118648
# 2204        Ladd McConkey  LAC  2024-25         NaN          NaN          NaN
# ...

# %% [markdown]
# Calculate Variable to determine how many targets were vacated in this team

# %% [markdown]
# Create variable to determine Depth Chart place

# %% [markdown]
# Turn Metrics into Per Game

# %%
df['PPR/G'] = df['PPR'] /df['G']
df['Pass Plays/G'] = df['pass_plays'] / df['player_game_count']
df['Receptions/G'] = df['receptions'] / df['player_game_count']
df['Routes/G'] = df['routes'] / df['player_game_count']
df['Targets/G'] = df['targets'] / df['player_game_count']
df['TD/G'] = df['touchdowns'] / df['player_game_count']
df['YDS/G'] = df['yards'] / df['player_game_count']
df['YAC/G'] = df['yards_after_catch'] / df['player_game_count']
df['RZ Targets/G'] = df['Tgt20'] / df['player_game_count']
df['P_Att/G'] = df['P_Att'] / df['Team_G']
df['P_Cmp/G'] = df['P_Cmp'] / df['Team_G']
df['P_TD/G'] = df['P_TD'] / df['Team_G']
df['P_Yds/G'] = df['P_Yds'] / df['Team_G']



df = df.drop(columns=['PPR', 'pass_plays', 'receptions', 'routes', 'targets', 'touchdowns', 'yards', 
                      'yards_after_catch', 'Tgt20', 'P_Att', 'P_Cmp', 'P_TD', 'P_Yds'])

# %% [markdown]
# Drop columns that were needed for joins but aren't needed anymore

# %%
df = df.drop(columns=['FantPos', 'G', 'GS', '-9999', 'prev_season', 'prev_2_season', 'player_id', 'player', 'position', 
                      'team_name', 'player_game_count', 'franchise_id', 'qb', 'qb_id', 'Team_G', 'prev_team', 'team_name_copy'])

# %% [markdown]
# Cleaning data to limit na's

# %%
# Temporary dropping to limit na's

df = df.drop(columns=['Improvement', 'PPR/G_prev2'])

df.to_csv('cleaned_wr_df.csv')

for col in df.columns:
    print(col + ": " + str(df[col].isnull().sum() / len(df[col])))

nonull = df.dropna()
nonull.to_csv('no_null_wr_df.csv')
# Out:
# Player: 0.0
# Tm: 0.0
# Season: 0.0
# Age: 0.0
# PosRank: 0.0
# PPR/G_prev: 0.3325153374233129
# avg_depth_of_target: 0.37791411042944784
# caught_percent: 0.37791411042944784
# grades_offense: 0.37791411042944784
# grades_pass_route: 0.37791411042944784
# route_rate: 0.37791411042944784
# slot_rate: 0.37791411042944784
# wide_rate: 0.37791411042944784
# inline_rate: 0.37791411042944784
# yprr: 0.37791411042944784
# man_grades_pass_route: 0.37955010224948876
# zone_grades_pass_route: 0.3791411042944785
# grades_pass: 0.11860940695296524
# pbe: 0.04294478527607362
# PPR/G: 0.12024539877300613
# Pass Plays/G: 0.37791411042944784
# Receptions/G: 0.37791411042944784
# Routes/G: 0.37791411042944784
# Targets/G: 0.37791411042944784
# TD/G: 0.37791411042944784
# YDS/G: 0.37791411042944784
# YAC/G: 0.37791411042944784
# RZ Targets/G: 0.4699386503067485
# P_Att/G: 0.04294478527607362
# P_Cmp/G: 0.04294478527607362
# P_TD/G: 0.04294478527607362
# P_Yds/G: 0.04294478527607362

# %%
# STILL NEED TO DO:

# Depth Chart place
# Vacated Target Share
# Improvement

# %%
##df = pff_receiving[pff_receiving['Season'] == '2023-24']
#df[['player', 'PPR PPG']].sort_values(['PPR PPG'], ascending=False).head(20)
